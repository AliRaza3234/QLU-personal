# %%
import chromadb
from chromadb.utils import embedding_functions
import json
from typing import Dict, List
import uuid

class ExemplarRetriever:
    def __init__(self):
        # Initialize ChromaDB client
        self.client = chromadb.Client()
        
        # Use default embedding function (all-MiniLM-L6-v2)
        self.embedding_fn = embedding_functions.DefaultEmbeddingFunction()
        
        # Get or create collection for exemplars
        self.collection = self.client.get_or_create_collection(
            name="exemplars",
            embedding_function=self.embedding_fn
        )

    def reset_collection(self):
        """Delete existing collection and create a new one"""
        try:
            self.client.delete_collection("exemplars")
        except:
            pass
        self.collection = self.client.create_collection(
            name="exemplars",
            embedding_function=self.embedding_fn
        )

    def add_exemplars(self, exemplars: List[Dict]):
        """Add multiple exemplars to the collection"""
        # First, reset the collection to start fresh
        self.reset_collection()
        
        ids = [str(uuid.uuid4()) for _ in exemplars]
        queries = [ex["query"] for ex in exemplars]
        metadatas = [
            {
                "rationale": ex["rationale"],
                "json_output": json.dumps(ex["json_output"])
            } 
            for ex in exemplars
        ]
        
        # Add to collection
        self.collection.add(
            ids=ids,
            documents=queries,
            metadatas=metadatas
        )

    def query_exemplars(self, 
                       query: str, 
                       n_results: int = 3) -> List[Dict]:
        """Query similar exemplars"""
        results = self.collection.query(
            query_texts=[query],
            n_results=n_results
        )
        
        # Process results
        exemplars = []
        for idx in range(len(results['ids'][0])):
            exemplar = {
                "query": results['documents'][0][idx],
                "rationale": results['metadatas'][0][idx]['rationale'],
                "json_output": json.loads(results['metadatas'][0][idx]['json_output'])
            }
            exemplars.append(exemplar)
            
        return exemplars

# %%
import json

with open('generated_input_output_pairs_v2.json') as f:
    gt_data_list = json.load(f)

# %%
len(gt_data_list)

# %%
import random

def randomize_queries(queries_list, seed=42, percentage=0.8):
    # create a list
    new_list = queries_list
    # extend the list with all the lists except the 'sample_data'
    # for query in queries_list:
    #     if query != 'sample_data':
    #         new_list.extend(queries_list[query])
    # randomize the list using a seed
    random.seed(42)
    random.shuffle(new_list)

    # add code for splitting it in three test, train, and validation with a percentage of perecentage
    train = new_list[:int(len(new_list)*percentage)]
    test = new_list[int(len(new_list)*percentage):int(len(new_list)*percentage)+int(len(new_list)*(1-percentage)/2)]
    validation = new_list[int(len(new_list)*percentage)+int(len(new_list)*(1-percentage)/2):]


    return train, test, validation

# %%
train, test, validation = randomize_queries(gt_data_list)

# %%
len(train)

# %%
import time

# Initialize retriever
retriever = ExemplarRetriever()
t1 = time.time()
# Add exemplars to store
retriever.add_exemplars(train)
print(f"Index time: {time.time() - t1:.2f} seconds")

# %%
query = test[15]['query']
print(query)

# %%
retriever.query_exemplars(query=query)

# %%
from together import Together
from dotenv import load_dotenv
import os

_ = load_dotenv('../.env')

print(os.environ.get('TOGETHER_API_KEY'))

# %%
messages = []

# %%
SYSTEM_L = """You are an AI assistant specialized in extracting management levels and job titles from queries. Your task is to analyze a given query and identify relevant management levels and job titles."""

USER_L = """
First, review these similar examples for inspiration:

<similar_examples>
{{SIMILAR_EXAMPLES}}
</similar_examples>

Now, consider the following query:

<query>
{{QUERY}}
</query>

Using the examples as a guide, analyze the query and extract the relevant management levels and job titles. Consider the following management levels:

['Partners,' 'Founder or Co-founder,' 'Board of Directors,' 'CSuite/Chiefs,' 'Executive VP or Sr. VP,' 'General Manager,' 'Manager,' 'Head,' 'Senior Partner,' 'Junior Partner,' 'VP,' 'Director,' 'Senior (All Senior-Level Individual Contributors),' 'Mid (All Mid-Level Individual Contributors),' 'Junior (All Junior-Level Individual Contributors)']

Guidelines for analysis:
1. Identify potential management levels and job titles in the query.
2. Normalize any abbreviations (e.g., CEO → Chief Executive Officer, VP → Vice President).
3. Separate management levels from job titles.
4. Exclude company names, locations, or other irrelevant information.

Before providing your final output, wrap your thought process in <analysis> tags. Focus on explaining your extraction and categorization choices rather than comparing directly to the examples. In your analysis:

1. List all potential management levels and job titles found in the query.
2. Explain your reasoning for categorizing each item as either a management level or job title.
3. Keep it moderate 


Your final output should follow this format:

<analysis>
[Your detailed thought process for extracting and categorizing the information]
</analysis>

<json_output>
{
    "management_levels": [],
    "titles": []
}
</json_output>

Remember to be thorough in your analysis but concise in your final output."""

# %%
def get_prompt(query, retriever):
        
    from jinja2 import Template
    exemplars = retriever.query_exemplars(query=query)
    user = Template(USER_L).render({
        "SIMILAR_EXAMPLES" : exemplars,
        "QUERY" : query
    })
    return [
        {'role' : 'system', 'content' : SYSTEM_L},
        {'role': 'user' , 'content' : user}
    ], exemplars

# %%
import re
import json

def extract_json_from_tags(text):
    # Use re to find the JSON string between <json_output> tags
    match = re.search(r'<json_output>(.*?)</json_output>', text, re.DOTALL)
    if match:
        json_str = match.group(1)
        # Convert the JSON string to a Python dictionary
        json_dict = json.loads(json_str)
        return json_dict
    else:
        return None

# %%
exemplar = test[25]

# %%
messages = get_prompt(exemplar['query'], retriever)

# %%
client = Together(api_key=os.environ.get('TOGETHER_API_KEY'))

response = client.chat.completions.create(
    model="meta-llama/Meta-Llama-3.1-8B-Instruct-Turbo-128K",
    messages=messages,
    max_tokens=1024,
    temperature=0.7,
    top_p=0.7,
    top_k=50,
    repetition_penalty=1,
    stop=["<|eot_id|>","<|eom_id|>"],
    stream=False
)
for token in response:
    if hasattr(token, 'choices'):
        print(token.choices[0].delta.content, end='', flush=True)

# %%
print(exemplar['json_output'])
print(response.choices[0].message.content)
# Out:
# {'management_levels': [], 'titles': ['Growth Hacker']}
# <analysis>
# 1. **Potential Management Levels and Job Titles**:
#    - Growth hackers
#    - Edtech startups
#    - K-12
#    - India
#
# 2. **Normalization**:
#    - No abbreviations need to be normalized in this query.
#
# 3. **Categorization**:
#    - **Management Levels**: None of the terms directly map to the predefined management levels. However, "growth hackers" implies a leadership role, but the term "hackers" is not typically associated with a specific management level.
#    - **Job Titles**: "Growth hackers" is a job title that refers to a specific role, which is a leadership position focused on growth within an organization. The term "growth hackers" is a common job title in the industry.
#
# 4. **Extraction and Categorization Choices**:
#    - I chose to categorize "growth hackers" as a job title because it specifies a role and is a common job title in the industry. The term "growth" implies a focus on leadership and growth within an organization, which aligns with the criteria for job titles.
#    - I excluded "edtech startups" and "K-12" because they are not job titles or management levels. They are industry-specific terms that provide context for the query.
#    - I excluded "India" because it is a location and not relevant to the extraction of management levels or job titles.
# </analysis>
#
# <json_output>
# {
#     "management_levels": [],
#     "job_titles": ["Growth Hacker"]
# }
# </json_output>

# %%
def get_together_api_response(exemplar, retriever):

    t1 = time.time()
    messages = get_prompt(exemplar['query'], retriever)
    t2 = time.time()
    client = Together(api_key=os.environ.get('TOGETHER_API_KEY'))

    response = client.chat.completions.create(
        model="meta-llama/Meta-Llama-3.1-8B-Instruct-Turbo-128K",
        messages=messages,
        max_tokens=1024,
        temperature=0.1,
        stop=["<|eot_id|>","<|eom_id|>"],
        stream=False
    )
    t3 = time.time()
    response_json = extract_json_from_tags(response.choices[0].message.content)
    return {
        "query" : exemplar['query'],
        "ground_truth" : exemplar['json_output'],
        "prediction" : response_json,
        "exact_match" : exemplar['json_output'] == response_json,
        "exemplar_retrieval_latency" : float(str(t2-t1)[:5]),
        "request_latency" : float(str(t3-t2)[:5])
    }

# %%
result = get_together_api_response(exemplar, retriever)

# %%
result
# Out:
# {'query': 'Associate Director Biostatistics or Senior RWE Data Scientist in pharmaceutical background in United States',
#  'ground_truth': {'management_levels': [],
#   'titles': ['Associate Director Biostatistics', 'Senior RWE Data Scientist']},
#  'prediction': {'management_levels': ['Associate Director'],
#   'titles': ['Biostatistics', 'Senior RWE Data Scientist']},
#  'exact_match': False,
#  'exemplar_retrieval_latency': 0.224,
#  'request_latency': 6.289}

# %%
import asyncio
import time
import os
import aiohttp
# from your_module import Together  # Assuming Together is synchronous

async def fetch_completion(api_key, messages, model, max_tokens, temperature, stop):
    url = 'https://api.together.xyz/chat/completions' # Replace with the actual endpoint
    headers = {'Authorization': f'Bearer {api_key}', 'Content-Type': 'application/json'}
    payload = {
        "model": model,
        "messages": messages,
        "max_tokens": max_tokens,
        "temperature": temperature,
        "stop": stop
    }

    async with aiohttp.ClientSession() as session:
        async with session.post(url, json=payload, headers=headers) as response:
            response_data = await response.json()
            return response_data

async def get_together_api_response_async(exemplar, retriever):
    t1 = time.time()
    messages, exemplars_chunks = get_prompt(exemplar['query'], retriever)
    t2 = time.time()

    # Perform the fetch asynchronously
    response_data = await fetch_completion(
        os.environ.get('TOGETHER_API_KEY'),
        messages,
        model="meta-llama/Meta-Llama-3.1-8B-Instruct-Turbo-128K",
        max_tokens=1024,
        temperature=0.1,
        stop=["<|eot_id|>", "<|eom_id|>"]
    )
    t3 = time.time()

    # Extract your JSON accordingly
    response_json = extract_json_from_tags(response_data['choices'][0]['message']['content'])

    return {
        "query": exemplar['query'],
        "ground_truth": exemplar['json_output'],
        "prediction": response_json,
        "exact_match": exemplar['json_output'] == response_json,
        "exemplar_retrieval_latency": float(str(t2-t1)[:5]),
        "request_latency": float(str(t3-t2)[:5]),
        "exemplars" : exemplars_chunks
    }

async def handle_batch(exemplars, retriever):
    tasks = [get_together_api_response_async(exemplar, retriever) for exemplar in exemplars]
    return await asyncio.gather(*tasks)

async def batched_call(exemplars, retriever):
    results = []
    batch_size = 10
    for i in range(0, len(exemplars), batch_size):
        print(f"Processing Batch {i}... ")
        batch = exemplars[i:i + batch_size]
        results.extend(await handle_batch(batch, retriever))
    return results

# Use await in the Jupyter Notebook cell
# results = await batched_call(test, retriever)

# %%
test.extend(validation)

# %%
len(test), len(validation)
# Out:
# (115, 58)

# %%
results = await batched_call(test, retriever)

# %%
len(results)
# Out:
# 115

# %%
count = 0
for item in results:
    print(item)
# Out:
# {'query': 'Find HR managers at AI/ML companies with a focus on scaling teams in Canada.', 'ground_truth': {'management_levels': [], 'titles': ['HR Manager', 'Human Resources Manager']}, 'prediction': {'management_levels': [], 'titles': ['HR Manager', 'HR Director', 'HR Vice President']}, 'exact_match': False, 'exemplar_retrieval_latency': 1.149, 'request_latency': 3.472}
# {'query': '"I’m interested in people holding senior engineering roles right now, especially those at Amazon with experience in cloud technologies', 'ground_truth': {'management_levels': [], 'titles': ['Senior Engineer', 'Senior Engineering Manager']}, 'prediction': {'management_levels': [], 'titles': ['Senior Engineering Roles']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.098, 'request_latency': 6.747}
# {'query': '"Searching for a Regional General Manager in the Lesser Antilles to oversee business operations and growth strategies."', 'ground_truth': {'management_levels': [], 'titles': ['Regional General Manager']}, 'prediction': {'management_levels': [], 'titles': ['Regional General Manager']}, 'exact_match': True, 'exemplar_retrieval_latency': 0.081, 'request_latency': 3.509}
# {'query': 'Seeking an accomplished General Manager to drive operational excellence across our Latin American markets', 'ground_truth': {'management_levels': ['General Manager'], 'titles': []}, 'prediction': {'management_levels': ['General Manager'], 'titles': []}, 'exact_match': True, 'exemplar_retrieval_latency': 0.086, 'request_latency': 4.002}
# {'query': 'Find me a Chief Data Officer with expertise in big data and cloud infrastructure, preferably with experience in the healthcare sector. Based in California or Texas.', 'ground_truth': {'management_levels': [], 'titles': ['Chief Data Officer']}, 'prediction': {'management_levels': [], 'titles': ['Chief Data Officer']}, 'exact_match': True, 'exemplar_retrieval_latency': 0.094, 'request_latency': 2.949}
# {'query': 'systematic credit portfolio manager', 'ground_truth': {'management_levels': [], 'titles': ['Systematic Credit Portfolio Manager']}, 'prediction': {'management_levels': [], 'titles': ['Portfolio Manager']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.092, 'request_latency': 5.088}
# {'query': 'Find growth marketing leaders at edtech platforms targeting emerging markets like India or Brazil.', 'ground_truth': {'management_levels': [], 'titles': ['Head of Growth Marketing', 'Director of Growth Marketing']}, 'prediction': {'management_levels': [], 'titles': ['Head of Growth Marketing', 'Director of Growth Marketing', 'VP of Growth Marketing']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.098, 'request_latency': 4.078}
# {'query': 'Looking for a Chief Technology Officer with a focus on mobile app development for a fintech startup. Ideally based in Latin America.', 'ground_truth': {'management_levels': [], 'titles': ['Chief Technology Officer', 'CTO']}, 'prediction': {'management_levels': [], 'titles': ['Chief Technology Officer']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.098, 'request_latency': 4.215}
# {'query': 'Leaders in blockchain technology', 'ground_truth': {'management_levels': [], 'titles': ['Blockchain Director', 'Head of Blockchain', 'Blockchain Lead']}, 'prediction': {'management_levels': [], 'titles': ['Leaders in Blockchain Technology']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.099, 'request_latency': 3.518}
# {'query': 'Retrieve profiles of individuals with 0–5 years of experience in blockchain development who live in Eastern Europe.', 'ground_truth': {'management_levels': [], 'titles': []}, 'prediction': {'management_levels': [], 'titles': []}, 'exact_match': True, 'exemplar_retrieval_latency': 0.099, 'request_latency': 3.595}
# {'query': 'Identify CTOs with experience in SaaS platforms that provide HR solutions in Southeast Asia.', 'ground_truth': {'management_levels': [], 'titles': ['CTO', 'Chief Technology Officer']}, 'prediction': {'management_levels': [], 'titles': ['CTO', 'Chief Technology Officer']}, 'exact_match': True, 'exemplar_retrieval_latency': 0.115, 'request_latency': 3.941}
# {'query': 'Find me people for the Chief Technology Officer role at Meta. The person must have expertise in AR/VR and metaverse technologies. Ideally based in California or Washington.', 'ground_truth': {'management_levels': [], 'titles': ['CTO', 'Chief Technology Officer']}, 'prediction': {'management_levels': [], 'titles': ['Chief Technology Officer']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.092, 'request_latency': 3.91}
# {'query': 'Executive search for pharmaceutical research directors', 'ground_truth': {'management_levels': [], 'titles': ['Director of Pharmaceutical Research']}, 'prediction': {'management_levels': [], 'titles': ['Director of Research', 'Research Director', 'Vice President of Research and Development', 'VP of R&D', 'Director of Clinical Research']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.137, 'request_latency': 4.701}
# {'query': 'Need founding team for deep tech startup focusing on computer vision and autonomous systems', 'ground_truth': {'management_levels': ['Founder or Co-founder'], 'titles': []}, 'prediction': {'management_levels': ['Founder or Co-founder'], 'titles': []}, 'exact_match': True, 'exemplar_retrieval_latency': 0.147, 'request_latency': 3.551}
# {'query': 'Senior Partner needed to drive strategic initiatives and deepen client relationships in the Northeast region', 'ground_truth': {'management_levels': ['Senior Partner'], 'titles': []}, 'prediction': {'management_levels': ['Senior Partner'], 'titles': []}, 'exact_match': True, 'exemplar_retrieval_latency': 0.136, 'request_latency': 3.92}
# {'query': 'Hire founding team members for fintech startup', 'ground_truth': {'management_levels': ['Founder or Co-founder'], 'titles': []}, 'prediction': {'management_levels': ['Founder or Co-founder'], 'titles': []}, 'exact_match': True, 'exemplar_retrieval_latency': 0.206, 'request_latency': 3.684}
# {'query': 'Find sales directors in healthcare AI companies based in Germany.', 'ground_truth': {'management_levels': [], 'titles': ['Sales Director']}, 'prediction': {'management_levels': ['Director'], 'titles': ['Director of Sales']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.107, 'request_latency': 3.155}
# {'query': 'Looking for founders who have successfully exited their startups in the last 3 years', 'ground_truth': {'management_levels': ['Founder or Co-founder'], 'titles': []}, 'prediction': {'management_levels': ['Founder or Co-founder'], 'titles': []}, 'exact_match': True, 'exemplar_retrieval_latency': 0.101, 'request_latency': 2.65}
# {'query': 'Show profiles of people who are currently in the google at cross platform development position as junior flutter developer, or junior react developer and have previously worked at Microsoft as intern or junior software developer, should have bachelors degree of Stanford in IT related fields, located in Texas or nearby areas.', 'ground_truth': {'management_levels': [], 'titles': ['junior flutter developer', 'junior react developer', 'intern', 'junior software developer']}, 'prediction': {'management_levels': [], 'titles': ['Junior Flutter Developer', 'Junior React Developer', 'Junior Software Developer', 'Software Development Intern']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.166, 'request_latency': 4.317}
# {'query': 'Searching for Operations Manager candidates in the Los Angeles area.', 'ground_truth': {'management_levels': [], 'titles': ['Operations Manager']}, 'prediction': {'management_levels': [], 'titles': ['Operations Manager']}, 'exact_match': True, 'exemplar_retrieval_latency': 0.103, 'request_latency': 3.091}
# {'query': 'Find me a Chief Human Resources Officer with experience scaling teams in the renewable energy sector. Preferably based in Germany.', 'ground_truth': {'management_levels': [], 'titles': ['CHRO', 'Chief Human Resources Officer']}, 'prediction': {'management_levels': ['CSuite/Chiefs'], 'titles': ['Chief Human Resources Officer']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.127, 'request_latency': 4.229}
# {'query': 'Generate a precise list of individuals currently serving as President, CEO, or COO in companies similar to Jawbone within the wearable technology sector. These companies focus on products such as fitness trackers, smartwatches, health monitoring devices, or other wearable electronics but do not necessarily have to manufacture them. The individuals should be based in the United States or Europe and hold an MBA degree. Exclude individuals from companies not focused on wearable technology. Precision is important', 'ground_truth': {'management_levels': [], 'titles': ['President', 'CEO', 'Chief Executive Officer', 'COO', 'Chief Operating Officer']}, 'prediction': {'management_levels': [], 'titles': ['President', 'Chief Executive Officer', 'Chief Operating Officer']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.111, 'request_latency': 3.974}
# {'query': 'Find me people for the VP of Product role at Shopify. The person must have strong expertise in e-commerce platforms and mobile product development. Ideally based in Canada.', 'ground_truth': {'management_levels': [], 'titles': ['VP of Product', 'Vice President of Product']}, 'prediction': {'management_levels': [], 'titles': ['Vice President of Product']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.103, 'request_latency': 4.366}
# {'query': "CISO and deputy CISO's with financial services experience that are based in the Washington DC / Baltimore region", 'ground_truth': {'management_levels': [], 'titles': ['CISO', 'Chief Information Security Officer', 'Deputy CISO']}, 'prediction': {'management_levels': [], 'titles': ['CISO', 'deputy CISO']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.112, 'request_latency': 4.426}
# {'query': 'Need a VP of Sales in the pharmaceutical industry with at least 10 years of experience.', 'ground_truth': {'management_levels': [], 'titles': ['VP of Sales', 'Vice President of Sales']}, 'prediction': {'management_levels': [], 'titles': ['VP of Sales', 'Vice President of Sales']}, 'exact_match': True, 'exemplar_retrieval_latency': 0.108, 'request_latency': 3.574}
# {'query': 'Associate Director Biostatistics or Senior RWE Data Scientist in pharmaceutical background in United States', 'ground_truth': {'management_levels': [], 'titles': ['Associate Director Biostatistics', 'Senior RWE Data Scientist']}, 'prediction': {'management_levels': ['Associate Director'], 'titles': ['Associate Director Biostatistics', 'Senior RWE Data Scientist']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.188, 'request_latency': 4.678}
# {'query': '"Hiring a General Manager in Northern Africa to oversee operations and strengthen regional business development."', 'ground_truth': {'management_levels': ['General Manager'], 'titles': []}, 'prediction': {'management_levels': [], 'titles': ['General Manager']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.095, 'request_latency': 2.882}
# {'query': 'Wanted: Directors for corporates in Seattle', 'ground_truth': {'management_levels': ['Director'], 'titles': []}, 'prediction': {'management_levels': ['Director'], 'titles': []}, 'exact_match': True, 'exemplar_retrieval_latency': 0.135, 'request_latency': 3.322}
# {'query': 'Director of Finance working at financial services based company which is located in US and have a revenue of greater then 0.1 million dollar. The should have a master degree in Finance realted feild. The person must have the experience of greater than 5 years. He must done his education from US', 'ground_truth': {'management_levels': [], 'titles': ['Director of Finance']}, 'prediction': {'management_levels': [], 'titles': ['Director of Finance']}, 'exact_match': True, 'exemplar_retrieval_latency': 0.104, 'request_latency': 3.0}
# {'query': 'Find someone currently at ibm or hpe,excluding those who have worked at oracle', 'ground_truth': {'management_levels': [], 'titles': []}, 'prediction': {'management_levels': [], 'titles': []}, 'exact_match': True, 'exemplar_retrieval_latency': 0.094, 'request_latency': 2.611}
# {'query': 'Find executives in Innovations Corp in San Francisco', 'ground_truth': {'management_levels': ['CSuite/Chiefs', 'Executive VP or Sr. VP', 'VP'], 'titles': []}, 'prediction': {'management_levels': [], 'titles': []}, 'exact_match': False, 'exemplar_retrieval_latency': 0.164, 'request_latency': 5.111}
# {'query': 'VP position available for an accomplished professional to establish and grow our European presence from our London headquarters', 'ground_truth': {'management_levels': ['VP'], 'titles': []}, 'prediction': {'management_levels': ['VP'], 'titles': []}, 'exact_match': True, 'exemplar_retrieval_latency': 0.12, 'request_latency': 3.507}
# {'query': 'List candidates who are current or past employees at Microsoft with 15–20 years of experience in cloud technologies.', 'ground_truth': {'management_levels': [], 'titles': []}, 'prediction': {'management_levels': [], 'titles': []}, 'exact_match': True, 'exemplar_retrieval_latency': 0.1, 'request_latency': 3.345}
# {'query': '"Hiring a Regional Vice President based in Western Europe to lead market expansion and operational strategies across the region."', 'ground_truth': {'management_levels': [], 'titles': ['Regional Vice President']}, 'prediction': {'management_levels': [], 'titles': ['Regional Vice President']}, 'exact_match': True, 'exemplar_retrieval_latency': 0.086, 'request_latency': 2.593}
# {'query': 'show senior level individual contributors currently working in Microsoft but have previous work experience of the mid level management in google.', 'ground_truth': {'management_levels': ['Senior (All Senior-Level Individual Contributors)', 'Mid (All Mid-Level Individual Contributors)'], 'titles': []}, 'prediction': {'management_levels': ['Mid (All Mid-Level Individual Contributors)'], 'titles': []}, 'exact_match': False, 'exemplar_retrieval_latency': 0.084, 'request_latency': 4.774}
# {'query': "Outstanding opportunity for Partners to shape our firm's growth trajectory and enhance market positioning", 'ground_truth': {'management_levels': ['Partners'], 'titles': []}, 'prediction': {'management_levels': ['Partners'], 'titles': []}, 'exact_match': True, 'exemplar_retrieval_latency': 0.094, 'request_latency': 2.956}
# {'query': 'Looking for a Chief Legal Officer with experience in intellectual property law for a healthtech startup. Ideally based in the U.S.', 'ground_truth': {'management_levels': [], 'titles': ['Chief Legal Officer']}, 'prediction': {'management_levels': [], 'titles': ['Chief Legal Officer']}, 'exact_match': True, 'exemplar_retrieval_latency': 0.092, 'request_latency': 3.98}
# {'query': 'Leaders in digital transformation', 'ground_truth': {'management_levels': [], 'titles': ['Chief Digital Officer', 'Head of Digital Transformation', 'Digital Transformation Manager']}, 'prediction': {'management_levels': [], 'titles': []}, 'exact_match': False, 'exemplar_retrieval_latency': 0.09, 'request_latency': 3.297}
# {'query': 'I need a Head of Engineering with strong experience in microservices architecture for a fintech company. Ideally based in New York.', 'ground_truth': {'management_levels': [], 'titles': ['Head of Engineering']}, 'prediction': {'management_levels': [], 'titles': ['Head of Engineering']}, 'exact_match': True, 'exemplar_retrieval_latency': 0.092, 'request_latency': 3.161}
# {'query': 'Find me people for the CTO role at Klarna. The person must have strong experience in payment systems and fintech platforms. Ideally based in Europe or California.', 'ground_truth': {'management_levels': [], 'titles': ['CTO', 'Chief Technology Officer']}, 'prediction': {'management_levels': [], 'titles': ['CTO', 'Chief Technology Officer']}, 'exact_match': True, 'exemplar_retrieval_latency': 0.087, 'request_latency': 2.917}
# {'query': 'Identify VPs of Engineering in telemedicine startups in the Asia-Pacific region.', 'ground_truth': {'management_levels': [], 'titles': ['VP of Engineering', 'Vice President of Engineering']}, 'prediction': {'management_levels': [], 'titles': ['Vice Presidents of Engineering', 'VPs of Engineering']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.254, 'request_latency': 2.866}
# {'query': 'Identify experts in digital transformation for energy sector SaaS platforms in the Nordics.', 'ground_truth': {'management_levels': [], 'titles': ['Digital Transformation Specialist', 'Digital Transformation Consultant', 'Digital Transformation Manager']}, 'prediction': {'management_levels': [], 'titles': ['Digital Transformation Specialist', 'Digital Transformation Manager', 'Digital Transformation Director', 'Digital Transformation Consultant', 'Digital Transformation Lead']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.1, 'request_latency': 5.163}
# {'query': '"Executive search for a Regional Director of Development in the Pacific Islands to support economic growth initiatives."', 'ground_truth': {'management_levels': [], 'titles': ['Regional Director of Development']}, 'prediction': {'management_levels': [], 'titles': ['Regional Director of Development']}, 'exact_match': True, 'exemplar_retrieval_latency': 0.091, 'request_latency': 3.644}
# {'query': 'Seeking a results-driven General Manager to pioneer our expansion initiatives across the Pacific Northwest territory', 'ground_truth': {'management_levels': ['General Manager'], 'titles': []}, 'prediction': {'management_levels': ['General Manager'], 'titles': []}, 'exact_match': True, 'exemplar_retrieval_latency': 0.095, 'request_latency': 2.413}
# {'query': "I'm looking for sales leaders at cybersecurity startups focused on enterprise markets in Southeast Asia.", 'ground_truth': {'management_levels': [], 'titles': ['Sales Director', 'Head of Sales', 'VP of Sales', 'Vice President of Sales']}, 'prediction': {'management_levels': [], 'titles': ['VP of Sales', 'Director of Sales', 'Head of Sales', 'Senior Sales Manager']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.092, 'request_latency': 3.055}
# {'query': 'Identify growth hackers for edtech startups with a focus on K-12 in India.', 'ground_truth': {'management_levels': [], 'titles': ['Growth Hacker']}, 'prediction': {'management_levels': [], 'titles': ['Growth Hacker']}, 'exact_match': True, 'exemplar_retrieval_latency': 0.09, 'request_latency': 3.818}
# {'query': 'Looking for a VP of Corporate Development with M&A experience in the tech sector. Preferably based in California.', 'ground_truth': {'management_levels': [], 'titles': ['VP of Corporate Development', 'Vice President of Corporate Development']}, 'prediction': {'management_levels': [], 'titles': ['VP of Corporate Development', 'Vice President of Corporate Development']}, 'exact_match': True, 'exemplar_retrieval_latency': 0.087, 'request_latency': 3.585}
# {'query': '"Seeking a Chief Executive Officer in the Baltic States to oversee business operations and drive regional growth."', 'ground_truth': {'management_levels': [], 'titles': ['Chief Executive Officer', 'CEO']}, 'prediction': {'management_levels': ['CSuite/Chiefs'], 'titles': ['Chief Executive Officer']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.095, 'request_latency': 4.608}
# {'query': 'In need of a Marketing Manager, but not a generic Manager role.', 'ground_truth': {'management_levels': [], 'titles': ['Marketing Manager']}, 'prediction': {'management_levels': ['Manager'], 'titles': ['Marketing Manager']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.092, 'request_latency': 2.67}
# {'query': 'Find me people for the CTO role at Coinbase. The person must have deep expertise in blockchain and cryptocurrency technology. Ideally based in California or Texas.', 'ground_truth': {'management_levels': [], 'titles': ['CTO', 'Chief Technology Officer']}, 'prediction': {'management_levels': [], 'titles': ['CTO', 'Chief Technology Officer']}, 'exact_match': True, 'exemplar_retrieval_latency': 0.09, 'request_latency': 3.086}
# {'query': 'Find software engineers in the UK with 0 years of experience who have graduated from Oxford University.', 'ground_truth': {'management_levels': [], 'titles': ['Software Engineer']}, 'prediction': {'management_levels': [], 'titles': ['Software Engineer']}, 'exact_match': True, 'exemplar_retrieval_latency': 0.094, 'request_latency': 4.403}
# {'query': 'Looking for executives with experience in luxury retail brands in European markets', 'ground_truth': {'management_levels': ['CSuite/Chiefs', 'Executive VP or Sr. VP', 'VP'], 'titles': []}, 'prediction': {'management_levels': ['CSuite/Chiefs', 'Executive VP or Sr. VP', 'VP'], 'titles': []}, 'exact_match': True, 'exemplar_retrieval_latency': 0.095, 'request_latency': 4.627}
# {'query': 'Share You said: i need to find a field recruiter ( or should I call it a talent acqusition specialist?) to manage 40 job recs at a time for a multi-utit franchisee of european wax center called wax center partners. Its a team of 1 and hte budget is $75k. Help me figure out what to prompt AI with so I can search Linkedin ChatGPT said: ChatGPT Memory updated To set up your LinkedIn search effectively, here’s a prompt that will help target the right candidates: Role Title: Field Recruiter or Talent Acquisition Specialist Industry: Beauty, Health/Wellness, or Multi-Unit Franchise Operations Skills/Experience: Proven experience handling high-volume recruitment (40+ requisitions at a time) Background in franchise recruiting, ideally in beauty or retail sectors Ability to work independently as a sole recruiter Knowledge of sourcing, screening, and hiring for entry-level to mid-level roles in customer service-focused environments Strong organizational and time management skills to manage multiple open positions effectively Budget: $75,000 annual salary Keywords to include: "High-volume recruiting," "Talent Acquisition Specialist," "Field Recruiter," "Retail recruiter," "Beauty industry recruiter," "Independent recruiter," "Multi-unit recruiter" "', 'ground_truth': {'management_levels': [], 'titles': ['Field Recruiter', 'Talent Acquisition Specialist']}, 'prediction': {'management_levels': [], 'titles': ['Field Recruiter', 'Talent Acquisition Specialist']}, 'exact_match': True, 'exemplar_retrieval_latency': 0.099, 'request_latency': 4.442}
# {'query': 'Looking for a Chief Revenue Officer with expertise in B2B SaaS sales in the European market. Candidates based in the U.K. are ideal.', 'ground_truth': {'management_levels': [], 'titles': ['Chief Revenue Officer']}, 'prediction': {'management_levels': [], 'titles': ['Chief Revenue Officer']}, 'exact_match': True, 'exemplar_retrieval_latency': 0.093, 'request_latency': 3.476}
# {'query': 'Find CTOs from the United States with 20–25 years of experience in tech leadership roles at current companies.', 'ground_truth': {'management_levels': [], 'titles': ['CTO', 'Chief Technology Officer']}, 'prediction': {'management_levels': [], 'titles': ['CTO', 'Chief Technology Officer']}, 'exact_match': True, 'exemplar_retrieval_latency': 0.092, 'request_latency': 3.123}
# {'query': 'GM or VP for grocery companies in finland, make sure they have relevant experience', 'ground_truth': {'management_levels': ['General Manager', 'VP'], 'titles': []}, 'prediction': {'management_levels': ['GM', 'VP'], 'titles': ['General Manager', 'Vice President']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.09, 'request_latency': 3.301}
# {'query': 'Find me people for the CTO role at Databricks. The person must have deep expertise in big data platforms and cloud computing. Ideally based in California or Washington.', 'ground_truth': {'management_levels': [], 'titles': ['CTO', 'Chief Technology Officer']}, 'prediction': {'management_levels': [], 'titles': ['CTO', 'Chief Technology Officer']}, 'exact_match': True, 'exemplar_retrieval_latency': 0.091, 'request_latency': 3.979}
# {'query': 'list of all CHRO (past and present) at newell brands', 'ground_truth': {'management_levels': [], 'titles': ['CHRO', 'Chief Human Resources Officer']}, 'prediction': {'management_levels': [], 'titles': ['Chief Human Resources Officer', 'CHRO']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.091, 'request_latency': 3.481}
# {'query': 'Find me people for the CFO role at Tesla. The person should have extensive experience in financial management for automotive companies. Ideally based in California or Texas.', 'ground_truth': {'management_levels': [], 'titles': ['CFO', 'Chief Financial Officer']}, 'prediction': {'management_levels': [], 'titles': ['CFO', 'Chief Financial Officer']}, 'exact_match': True, 'exemplar_retrieval_latency': 0.089, 'request_latency': 3.576}
# {'query': 'vice president r&d haircare laundry ', 'ground_truth': {'management_levels': [], 'titles': ['Vice President of R&D']}, 'prediction': {'management_levels': [], 'titles': ['Vice President of R&D in Haircare Laundry', 'VP of R&D in Haircare Laundry']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.087, 'request_latency': 2.351}
# {'query': 'Specialists in supply chain optimization', 'ground_truth': {'management_levels': [], 'titles': ['Specialist in Supply Chain Optimization']}, 'prediction': {'management_levels': [], 'titles': ['Specialists in supply chain optimization']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.22, 'request_latency': 3.191}
# {'query': 'Junior Partner position available at our prestigious firm to support growth and client engagement initiatives', 'ground_truth': {'management_levels': ['Junior Partner'], 'titles': []}, 'prediction': {'management_levels': ['Junior Partner'], 'titles': []}, 'exact_match': True, 'exemplar_retrieval_latency': 0.111, 'request_latency': 2.809}
# {'query': 'Exceptional opportunity for an Executive VP or Sr. VP to lead our global expansion and strategic partnership initiatives', 'ground_truth': {'management_levels': ['Executive VP or Sr. VP'], 'titles': []}, 'prediction': {'management_levels': ['Executive VP or Sr. VP'], 'titles': []}, 'exact_match': True, 'exemplar_retrieval_latency': 0.09, 'request_latency': 3.059}
# {'query': 'I need finance directors at AI/ML startups based in Israel.', 'ground_truth': {'management_levels': [], 'titles': ['Finance Director']}, 'prediction': {'management_levels': ['Director'], 'titles': ['Finance Director', 'Director of Finance', 'Financial Director']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.086, 'request_latency': 3.307}
# {'query': 'Seeking transformational CSuite/Chiefs to lead our global expansion and digital transformation journey', 'ground_truth': {'management_levels': ['CSuite/Chiefs'], 'titles': []}, 'prediction': {'management_levels': ['CSuite/Chiefs'], 'titles': []}, 'exact_match': True, 'exemplar_retrieval_latency': 0.09, 'request_latency': 2.947}
# {'query': 'Identify CTOs with experience in developing AR/VR platforms for retail companies in Europe.', 'ground_truth': {'management_levels': [], 'titles': ['CTO', 'Chief Technology Officer']}, 'prediction': {'management_levels': [], 'titles': ['CTO', 'Chief Technology Officer']}, 'exact_match': True, 'exemplar_retrieval_latency': 0.106, 'request_latency': 3.238}
# {'query': 'I need data scientists in fintech startups with expertise in AI and machine learning in the U.S.', 'ground_truth': {'management_levels': [], 'titles': ['Data Scientist']}, 'prediction': {'management_levels': [], 'titles': ['Data Scientist']}, 'exact_match': True, 'exemplar_retrieval_latency': 0.088, 'request_latency': 4.425}
# {'query': 'Identify head of customer success roles in SaaS-based companies with a focus on AI/ML products in California.', 'ground_truth': {'management_levels': [], 'titles': ['Head of Customer Success']}, 'prediction': {'management_levels': [], 'titles': ['Head of Customer Success Roles', 'Head of Customer Success']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.097, 'request_latency': 2.599}
# {'query': 'Looking for a chief strategy officer with a strong background in financial services for a role at Big Bank Corp.', 'ground_truth': {'management_levels': [], 'titles': ['Chief Strategy Officer']}, 'prediction': {'management_levels': [], 'titles': ['Chief Strategy Officer']}, 'exact_match': True, 'exemplar_retrieval_latency': 0.088, 'request_latency': 3.226}
# {'query': 'owners of ketamine psychiatry clinic in the US', 'ground_truth': {'management_levels': ['Founder or Co-founder'], 'titles': []}, 'prediction': {'management_levels': ['Owner'], 'titles': []}, 'exact_match': False, 'exemplar_retrieval_latency': 0.087, 'request_latency': 2.213}
# {'query': 'List profiles of individual contributors with 2–3 years of experience in data analytics roles, currently in Australia.', 'ground_truth': {'management_levels': ['Junior (All Junior-Level Individual Contributors)'], 'titles': []}, 'prediction': {'management_levels': [], 'titles': ['Individual Contributor', 'Data Analyst', 'Data Scientist']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.091, 'request_latency': 4.126}
# {'query': 'Please find CEO of private equity companies in the US that are less than $600 million in revenue that manufacture chemcials for rubber and tires', 'ground_truth': {'management_levels': [], 'titles': ['CEO', 'Chief Executive Officer']}, 'prediction': {'management_levels': [], 'titles': ['Chief Executive Officer']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.093, 'request_latency': 3.223}
# {'query': 'Identify HR directors in AI/ML startups focused on scaling engineering teams in the U.K.', 'ground_truth': {'management_levels': [], 'titles': ['HR Director']}, 'prediction': {'management_levels': [], 'titles': ['Director of Human Resources', 'Head of HR', 'VP of HR']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.09, 'request_latency': 3.097}
# {'query': "I'm looking for business development leaders in AI/ML SaaS companies that focus on healthcare in Canada.", 'ground_truth': {'management_levels': [], 'titles': ['Chief Business Development Officer', 'CBO', 'Vice President of Business Development', 'VP of Business Development', 'Director of Business Development']}, 'prediction': {'management_levels': [], 'titles': ['Head of Business Development', 'Director of Business Development', 'VP of Business Development']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.088, 'request_latency': 2.566}
# {'query': 'Seek sales executives who demonstrate a thorough understanding of B2B sales processes, CRM tools, lead generation strategies, and negotiation techniques. Candidates should be based in Toronto, Canada, and specifically exclude those with ties to the technology industry.', 'ground_truth': {'management_levels': [], 'titles': ['Chief Sales Officer', 'Senior VP of Sales', 'Senior Vice President of Sales', 'VP of Sales', 'Vice President of Sales']}, 'prediction': {'management_levels': [], 'titles': ['Head of Sales', 'Director of Sales', 'VP of Sales', 'Sales Manager']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.082, 'request_latency': 3.798}
# {'query': '"Hiring a Chief of Regional Partnerships in ASEAN to manage cross-border projects and partnership initiatives."', 'ground_truth': {'management_levels': [], 'titles': ['Chief of Regional Partnerships']}, 'prediction': {'management_levels': [], 'titles': ['Chief of Regional Partnerships']}, 'exact_match': True, 'exemplar_retrieval_latency': 0.079, 'request_latency': 2.539}
# {'query': 'Specialists in aerospace engineering from NASA or SpaceX', 'ground_truth': {'management_levels': [], 'titles': ['Aerospace Engineering Specialist', 'Aerospace Engineer']}, 'prediction': {'management_levels': [], 'titles': ['Aerospace Engineer', 'Aerospace Systems Engineer', 'Aerospace Research Scientist', 'Aerospace Engineer Manager']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.078, 'request_latency': 2.707}
# {'query': 'Searching for an analytics whiz to join our team as a data science expert in Los Angeles.', 'ground_truth': {'management_levels': [], 'titles': ['Data Science Expert']}, 'prediction': {'management_levels': [], 'titles': []}, 'exact_match': False, 'exemplar_retrieval_latency': 0.087, 'request_latency': 3.615}
# {'query': 'Identify HR leaders at AI-powered healthcare companies in Canada.', 'ground_truth': {'management_levels': [], 'titles': ['Chief Human Resources Officer', 'CHRO', 'Senior Vice President of Human Resources', 'SVP of HR', 'Vice President of Human Resources', 'VP of HR']}, 'prediction': {'management_levels': [], 'titles': ['HR Leader']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.088, 'request_latency': 5.148}
# {'query': 'Find engineers with 15 plus years of experience who have worked at Tesla and specialize in mechanical systems.', 'ground_truth': {'management_levels': [], 'titles': ['Engineer']}, 'prediction': {'management_levels': [], 'titles': ['Engineer']}, 'exact_match': True, 'exemplar_retrieval_latency': 0.09, 'request_latency': 3.35}
# {'query': 'Identify CEO, CMO, CSO, COO and CTO of a List of companies', 'ground_truth': {'management_levels': [], 'titles': ['CEO', 'Chief Executive Officer', 'CMO', 'Chief Marketing Officer', 'CSO', 'Chief Security Officer', 'COO', 'Chief Operating Officer', 'CTO', 'Chief Technology Officer']}, 'prediction': {'management_levels': [], 'titles': ['Chief Executive Officer', 'Chief Marketing Officer', 'Chief Strategy Officer', 'Chief Operating Officer', 'Chief Technology Officer']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.246, 'request_latency': 5.76}
# {'query': 'Identify CFOs in climate tech startups with a focus on sustainability in Europe.', 'ground_truth': {'management_levels': [], 'titles': ['CFO', 'Chief Financial Officer']}, 'prediction': {'management_levels': [], 'titles': ['CFO', 'Chief Financial Officer']}, 'exact_match': True, 'exemplar_retrieval_latency': 0.088, 'request_latency': 3.31}
# {'query': 'Pursue candidates for the role of mobile application developer who possess a deep-seated expertise in the intricacies of iOS and Android ecosystems, showcasing proficiency in Swift and Kotlin programming languages, coupled with a robust understanding of user interface design principles and app testing methodologies. Candidates should be geographically anchored within the Seattle, Washington metropolitan area, while explicitly excluding individuals with any affiliations to the gaming sector.', 'ground_truth': {'management_levels': [], 'titles': ['Mobile Application Developer']}, 'prediction': {'management_levels': [], 'titles': ['Mobile Application Developer', 'iOS Developer', 'Android Developer', 'Swift Developer', 'Kotlin Developer', 'User Interface Designer', 'App Tester']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.092, 'request_latency': 5.72}
# {'query': 'Identify design leaders in AR/VR startups in the U.S.', 'ground_truth': {'management_levels': [], 'titles': ['Chief Design Officer', 'CDO', 'Head of Design', 'Design Director']}, 'prediction': {'management_levels': [], 'titles': ['Design Director']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.085, 'request_latency': 2.739}
# {'query': 'Seeking a VP with experience in leading multinational teams and managing complex stakeholder relationships', 'ground_truth': {'management_levels': ['VP'], 'titles': []}, 'prediction': {'management_levels': ['VP'], 'titles': []}, 'exact_match': True, 'exemplar_retrieval_latency': 0.085, 'request_latency': 2.624}
# {'query': 'Display profiles of senior project managers with exactly 10 years of experience working in Europe who specialize in Agile methodologies.', 'ground_truth': {'management_levels': [], 'titles': ['Senior Project Manager']}, 'prediction': {'management_levels': [], 'titles': ['Senior Project Manager']}, 'exact_match': True, 'exemplar_retrieval_latency': 0.083, 'request_latency': 3.102}
# {'query': 'Chemical engineers at companies with Downstream refining with 20+ years of experience based in Texas', 'ground_truth': {'management_levels': [], 'titles': ['Chemical Engineer']}, 'prediction': {'management_levels': [], 'titles': ['Chemical engineers']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.097, 'request_latency': 3.699}
# {'query': 'Find me a Head of Marketing with expertise in scaling consumer tech brands. Preferably based in the U.S. 44', 'ground_truth': {'management_levels': [], 'titles': ['Head of Marketing']}, 'prediction': {'management_levels': ['Head'], 'titles': ['Head of Marketing']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.112, 'request_latency': 2.44}
# {'query': 'Executive VP or Sr. VP needed to accelerate growth and drive innovation across the Asia-Pacific region', 'ground_truth': {'management_levels': ['Executive VP or Sr. VP'], 'titles': []}, 'prediction': {'management_levels': ['Executive VP or Sr. VP'], 'titles': []}, 'exact_match': True, 'exemplar_retrieval_latency': 0.21, 'request_latency': 2.441}
# {'query': 'Display profiles of senior managers with 7–10 years of experience leading marketing teams in Southeast Asia.', 'ground_truth': {'management_levels': ['Manager'], 'titles': []}, 'prediction': {'management_levels': ['Senior (All Senior-Level Individual Contributors)'], 'titles': ['Senior Manager']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.123, 'request_latency': 4.913}
# {'query': 'Executive VP or Sr. VP vacancy - Global expansion strategy focus', 'ground_truth': {'management_levels': ['Executive VP or Sr. VP'], 'titles': []}, 'prediction': {'management_levels': ['Executive VP or Sr. VP'], 'titles': []}, 'exact_match': True, 'exemplar_retrieval_latency': 0.294, 'request_latency': 2.569}
# {'query': 'Find me people for the Chief Marketing Officer role at Zoom. The person should have experience in driving growth for B2B SaaS companies. Ideally based in California.', 'ground_truth': {'management_levels': [], 'titles': ['Chief Marketing Officer', 'CMO']}, 'prediction': {'management_levels': [], 'titles': ['Chief Marketing Officer']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.095, 'request_latency': 2.572}
# {'query': 'We need a ciso for our security firm with a strong background in encryption and networking domains.', 'ground_truth': {'management_levels': [], 'titles': ['CISO', 'Chief Information Security Officer']}, 'prediction': {'management_levels': [], 'titles': ['CISO', 'Chief Information Security Officer']}, 'exact_match': True, 'exemplar_retrieval_latency': 0.097, 'request_latency': 2.646}
# {'query': 'show senior level individual contributors currently working in Microsoft or have previous work experience of the mid level management in google.', 'ground_truth': {'management_levels': ['Senior (All Senior-Level Individual Contributors)', 'Mid (All Mid-Level Individual Contributors)'], 'titles': []}, 'prediction': {'management_levels': ['Senior', 'Mid'], 'titles': []}, 'exact_match': False, 'exemplar_retrieval_latency': 0.101, 'request_latency': 4.678}
# {'query': 'Find executives who have led successful M&A transactions in the past 5 years', 'ground_truth': {'management_levels': [], 'titles': ['Chief M&A Officer', 'Head of M&A', 'Director of M&A']}, 'prediction': {'management_levels': [], 'titles': []}, 'exact_match': False, 'exemplar_retrieval_latency': 0.092, 'request_latency': 2.366}
# {'query': 'Source CEO, Vice President and Director of Manufacturing in Big Software Automotive companies, and located in California', 'ground_truth': {'management_levels': ['VP'], 'titles': ['CEO', 'Chief Executive Officer', 'Director of Manufacturing']}, 'prediction': {'management_levels': ['VP'], 'titles': ['Source CEO', 'Director of Manufacturing']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.093, 'request_latency': 3.197}
# {'query': 'I have a few Director and VP positions opened in my firm. I want to hire candidates from Harvard School of Law', 'ground_truth': {'management_levels': ['Director', 'VP'], 'titles': []}, 'prediction': {'management_levels': ['Director', 'VP'], 'titles': []}, 'exact_match': True, 'exemplar_retrieval_latency': 0.102, 'request_latency': 4.033}
# {'query': 'Find me suitable Chairman of a Norwegian Utility and Power company located on the West Coast of Norway. It is preferred with candidates from the region', 'ground_truth': {'management_levels': ['Board of Directors'], 'titles': []}, 'prediction': {'management_levels': [], 'titles': ['Chairman', 'Chairman of the Board']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.096, 'request_latency': 2.518}
# {'query': 'Recruiting for fresh graduate engineering roles at Startup Inc.', 'ground_truth': {'management_levels': [], 'titles': ['Junior Engineer', 'Graduate Engineer']}, 'prediction': {'management_levels': [], 'titles': []}, 'exact_match': False, 'exemplar_retrieval_latency': 0.093, 'request_latency': 4.873}
# {'query': 'Looking to bring aboard a Director who can champion our global sustainability initiatives and drive meaningful impact', 'ground_truth': {'management_levels': ['Director'], 'titles': []}, 'prediction': {'management_levels': ['Director'], 'titles': ['Sustainability Director', 'Director of Sustainability']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.095, 'request_latency': 2.282}
# {'query': 'Identify HR leaders in SaaS companies who have experience scaling remote teams in Europe.', 'ground_truth': {'management_levels': [], 'titles': ['Chief Human Resources Officer', 'VP of Human Resources', 'Director of Human Resources']}, 'prediction': {'management_levels': [], 'titles': ['HR Leader', 'Human Resources Leader']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.267, 'request_latency': 5.713}
# {'query': 'data analysts that use powerbi at a private equity firm', 'ground_truth': {'management_levels': [], 'titles': ['Data Analyst']}, 'prediction': {'management_levels': [], 'titles': ['Data Analyst']}, 'exact_match': True, 'exemplar_retrieval_latency': 0.085, 'request_latency': 2.302}
# {'query': 'Identify product leaders at telemedicine platforms in Latin America.', 'ground_truth': {'management_levels': [], 'titles': ['Product Manager', 'Senior Product Manager', 'Head of Product']}, 'prediction': {'management_levels': [], 'titles': ['Product Leader']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.093, 'request_latency': 2.078}
# {'query': 'Looking for managers with expertise in Agile methodologies', 'ground_truth': {'management_levels': [], 'titles': ['Agile Manager', 'Agile Project Manager']}, 'prediction': {'management_levels': ['Manager'], 'titles': []}, 'exact_match': False, 'exemplar_retrieval_latency': 0.086, 'request_latency': 3.725}
# {'query': 'Need a Project Manager with Agile experience at XYZ Corporation.', 'ground_truth': {'management_levels': [], 'titles': ['Project Manager']}, 'prediction': {'management_levels': [], 'titles': ['Project Manager']}, 'exact_match': True, 'exemplar_retrieval_latency': 0.093, 'request_latency': 2.03}
# {'query': 'Seeking a Senior Project Manager familiar with construction management.', 'ground_truth': {'management_levels': [], 'titles': ['Senior Project Manager']}, 'prediction': {'management_levels': [], 'titles': ['Senior Project Manager']}, 'exact_match': True, 'exemplar_retrieval_latency': 0.091, 'request_latency': 2.306}
# {'query': 'Find VPs of Product Management in AI-powered fintech platforms in the U.K.', 'ground_truth': {'management_levels': [], 'titles': ['VP of Product Management', 'Vice President of Product Management']}, 'prediction': {'management_levels': [], 'titles': ['Vice President of Product Management', 'Product Management Director', 'Product Management Lead']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.193, 'request_latency': 2.068}
# {'query': 'Transformational Director role implementing organizational change', 'ground_truth': {'management_levels': [], 'titles': ['Transformational Director']}, 'prediction': {'management_levels': ['Director'], 'titles': []}, 'exact_match': False, 'exemplar_retrieval_latency': 0.089, 'request_latency': 1.946}
# {'query': 'Identify growth marketing experts in fintech startups in Latin America.', 'ground_truth': {'management_levels': [], 'titles': ['Growth Marketing Expert']}, 'prediction': {'management_levels': [], 'titles': ['Growth Marketing Expert']}, 'exact_match': True, 'exemplar_retrieval_latency': 0.08, 'request_latency': 3.566}
# {'query': 'Looking for a Chief Technology Officer with experience in scaling AI platforms in the cybersecurity industry. Preferably based in Israel.', 'ground_truth': {'management_levels': [], 'titles': ['CTO', 'Chief Technology Officer']}, 'prediction': {'management_levels': [], 'titles': ['Chief Technology Officer']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.081, 'request_latency': 2.656}
# {'query': 'Find me marketing leaders in fintech startups focused on customer acquisition in Southeast Asia.', 'ground_truth': {'management_levels': [], 'titles': ['Chief Marketing Officer', 'CMO', 'Vice President of Marketing', 'VP of Marketing', 'Senior Vice President of Marketing', 'Senior VP of Marketing']}, 'prediction': {'management_levels': [], 'titles': ['Marketing Director', 'Marketing Manager', 'VP of Marketing', 'Director of Marketing']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.225, 'request_latency': 2.887}
# {'query': 'Find sales executives in healthtech startups focusing on insurance tech in Europe.', 'ground_truth': {'management_levels': [], 'titles': ['Chief Sales Officer', 'CSO', 'Senior Vice President of Sales', 'Senior VP of Sales', 'Vice President of Sales', 'VP of Sales']}, 'prediction': {'management_levels': ['CSuite/Chiefs', 'Executive VP or Sr. VP', 'VP'], 'titles': []}, 'exact_match': False, 'exemplar_retrieval_latency': 0.086, 'request_latency': 1.982}
# {'query': 'show me only python back-end developers who have 5 years of experience and currently located in new york.', 'ground_truth': {'management_levels': [], 'titles': ['Python Back-End Developer']}, 'prediction': {'management_levels': [], 'titles': ['Python Back-end Developer']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.082, 'request_latency': 2.097}
# {'query': 'Need a Manager for our Chicago office', 'ground_truth': {'management_levels': ['Manager'], 'titles': []}, 'prediction': {'management_levels': ['Manager'], 'titles': []}, 'exact_match': True, 'exemplar_retrieval_latency': 0.075, 'request_latency': 1.915}
# {'query': '"Looking for a Chief Financial Officer based in Northern Europe with expertise in optimizing financial operations across the region."', 'ground_truth': {'management_levels': [], 'titles': ['CFO', 'Chief Financial Officer']}, 'prediction': {'management_levels': [], 'titles': ['Chief Financial Officer']}, 'exact_match': False, 'exemplar_retrieval_latency': 0.074, 'request_latency': 1.38}

# %%
# Out:
# 0

# %% [markdown]
# # Loading Fine Tuned Model results

# %%
import time
from jinja2 import Template
def get_prompt_company_generation(query):
    SYSTEM = """Your name is Lisa and you are intelligent assistant tasked with listing down companies according to mentioned requirements. Make sure to strictly follow the output format."""
    USER = """<Instructions>
            - Based on the given prompt generate companies/institutions/organizations based on the context of the query.
            **Case: 1**
                - If a tasks mentions specific company names or nouns only, generate those. You are to consider nouns as company names even if you're unfamiliar with them. If they refer to some product or something you are sure isnt a company, they belong to case 4.
                - Any noun mentioned in the prompt is to be considered a company word for word. If you don't know that particular company just give "company name~location" in your output.
                    e.g. For the prompt "Apophis"
                        **Good Output**: "Apophis~United States "
                        **Bad Output**: "Apophis~United States", "Apple~United States" ...
                        **Bad Output**: "ApophisTech~United States", "ApophisFinance~United States" ...
                - This case only caters when only company name(s) is present and not the industry or relevant terms. In case of industry, refer below cases
            **Case: 2**
                - If the task requires or mentions lists of companies or similar companies (this also caters "companies like") always try to achieve 50 companies.
            **Case: 3**
                - If the task has company names along with specificly mentioned requirement for a list.
                **Case: 3.1**
                    - If the prompt asks for companies and thier similar companies, Generate those names and then the rest of the list.
                **Case: 3.2**
                    - If the prompt explicitly only asks for companies similar to the names, Only generate the list without those names.
            **Case: 4**
                - If the prompt has any mention that isnt from above but companies can get generated for them, generate.
        </Instructions>
        <Output Format>
            - The section after the thought process where the companies are listed down must be enclosed in xml tag of "Companies". The system will fail otherwise
            - Below is the example of required tags in list section:
            <Companies>
                1. Company Name~Location
                ...
            </Companies>
        </Output Format>
        <Important>
            - Generate the most commonly used or known names for the companies. Don't add things like LLC, Ltd, Inc etc.
            - Location can only be country names. If you don't know the location just add 'United States'.
            - Always treat individual company requirements separately. E.g. "Companies with $500M-$2B in revenue and healthcare companies." here you need to generate companies with $500M–$2B in revenue and companies from healthcare seperately.
            - Once you've given me a company don't give that company again!
            - Case should be decided without considering the sizes requirements mentioned by the user.
            - Dont mention the output format or tags anywhere in the thought process.
            - Even if its being asked not to include a company, return that name as well.
        </Important>
        <Perform Task>
            - Take a deep breath and understand the instructions. Then tell your thought process and only then generate.
            - Generate a numbered list containing company name and it's location separated by a delimiter '~' Keeping the mentioned prompt in view.
            - After your thought process, add a tag of <Companies> and then generate the list of companies. failing to do so would fail the system.
        </Perform Task>
        <Prompt>
        {{query}}
        </Prompt>
        """
    user = Template(USER).render({"query": query})
    messages = [{'role' : 'system', 'content' : SYSTEM},{'role':'user', 'content': user}]
    
    
import time
import os
from together import Together

async def get_together_api_response_async_v2(query):
    t1 = time.time()
    messages = get_prompt_company_generation(query)
    # messages = get_prompt_brief(exemplar['query'], )
    # print(messages)
    t2 = time.time()

    client = Together(api_key=os.environ.get('TOGETHER_API_KEY'))

    response = client.chat.completions.create(
        model="meta-llama/Meta-Llama-3.1-8B-Instruct-Turbo-128K",
        messages=messages,
        max_tokens=1024,
        temperature=0.7,
        top_p=0.7,
        top_k=50,
        repetition_penalty=1,
        stop=["<|eot_id|>","<|eom_id|>"],
        stream=False
    )
    
    t3 = time.time()
import asyncio
import aiohttp
import time
from typing import List, Dict
import logging

# Configure logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# Your queries list
queries = [
    "Vice President of IT and Technology at logistics and distribution companies based in the United States with a revenue of over $25B and pretend you are a financial analyst and technical. All firms that are target companies for Central Garden & Pet in their search for a CFO of their pet segment business.",
    "Find me marketing leaders in fintech startups focused on customer acquisition in Southeast Asia.",
    "I need product managers in e-commerce platforms with experience in scaling marketplaces in the U.S.",
    "Identify UX/UI designers who specialize in mobile app design for fintech applications in Europe.",
    "I'm looking for CTOs at blockchain companies with expertise in Web3 and DeFi in Singapore.",
    "Find senior data scientists in healthcare AI startups based in Canada.",
    "I need sales directors at SaaS companies focused on B2B enterprise sales in the U.K.",
    "Find CPOs (Chief Product Officers) in cybersecurity startups with experience in building B2C products in the U.S.",
    "Identify head of customer success roles in SaaS-based companies with a focus on AI/ML products in California.",
    "Find growth marketing leaders at edtech platforms targeting emerging markets like India or Brazil.",
    "I'm looking for CFOs with fundraising experience in climate tech startups based in Europe.",
    "Identify VPs of Engineering in telemedicine startups in the Asia-Pacific region.",
    "I need blockchain developers who have worked on decentralized finance (DeFi) projects in Africa.",
    "Find machine learning engineers working on computer vision in autonomous vehicle companies in the U.S.",
    "Identify HR leaders in SaaS companies who have experience scaling remote teams in Europe.",
    "I need C-suite executives with expertise in scaling SaaS platforms in Latin America.",
    "Find operations managers at logistics startups using AI for route optimization in Southeast Asia.",
    "I'm looking for business development leaders in AI/ML SaaS companies that focus on healthcare in Canada.",
    "Identify CTOs with experience in developing AR/VR platforms for retail companies in Europe.",
    "Find CEOs with experience in growing SaaS startups from Series A to IPO in the U.S.",
    "I need heads of sales in financial services companies focusing on AI/ML solutions in New York.",
    "Find people for the COO role at deep tech AI companies based in Japan.",
    "Identify marketing heads at wellness tech startups with experience in D2C channels in California.",
    "I'm looking for chief legal officers in cybersecurity firms in Israel.",
    "Find engineering leaders at mobility-as-a-service (MaaS) companies in Europe.",
    "Identify experts in digital transformation for energy sector SaaS platforms in the Nordics.",
    "I need people for the VP of Operations role in B2B SaaS companies based in Singapore.",
    "Find product marketing managers in medtech startups in the U.S.",
    "Identify heads of corporate strategy at AI-driven SaaS companies focused on fintech in Europe.",
    "I'm looking for CROs (Chief Revenue Officers) at climate tech startups based in Australia."
]

async def shorten_prompt(session: aiohttp.ClientSession, query: str) -> Dict:
    """Async function to call the shortening API"""
    url = "https://qlu2-ai-backend-7wzmpo3asa-uc.a.run.app/shorten_prompt"
    headers = {
        'accept': 'application/json',
        'Content-Type': 'application/json'
    }
    payload = {
        "prompt": query,
        "agent": "dual"
    }
    
    try:
        async with session.post(url, headers=headers, json=payload) as response:
            return await response.json()
    except Exception as e:
        logger.error(f"Error in shorten_prompt: {str(e)}")
        return None

async def together_api_response(query: str) -> Dict:
    """Async function to call the Together API"""
    # Replace with your actual Together API implementation
    t1 = time.time()
    
    t2 = time.time()
    return {"status": "success", "query": query, "response": response}

async def process_query(session: aiohttp.ClientSession, query: str, semaphore: asyncio.Semaphore):
    """Process a single query with timing"""
    async with semaphore:
        start_time = time.time()
        try:
            # Get shortened prompt
            shortened = await shorten_prompt(session, query)
            if not shortened:
                return {"query": query, "status": "failed", "time": time.time() - start_time}

            # Process both current and past
            tasks = []
            for key in ['current', 'past']:
                if shortened.get(key):
                    tasks.append(together_api_response(session, shortened[key]))
            
            if tasks:
                results = await asyncio.gather(*tasks)
            
            return {
                "query": query,
                "status": "success",
                "time": time.time() - start_time,
                "results": results if tasks else None
            }
        except Exception as e:
            logger.error(f"Error processing query '{query}': {str(e)}")
            return {"query": query, "status": "failed", "error": str(e)}

async def process_all_queries(queries: List[str], concurrent_limit: int = 5):
    """Process all queries concurrently"""
    async with aiohttp.ClientSession() as session:
        semaphore = asyncio.Semaphore(concurrent_limit)
        tasks = [process_query(session, query, semaphore) for query in queries]
        return await asyncio.gather(*tasks)

# Function to run in Jupyter
async def run_processing():
    start_time = time.time()
    results = await process_all_queries(queries)
    total_time = time.time() - start_time
    
    # Print summary
    successful = sum(1 for r in results if r['status'] == 'success')
    print(f"\nProcessing Summary:")
    print(f"Total queries: {len(results)}")
    print(f"Successful: {successful}")
    print(f"Failed: {len(results) - successful}")
    print(f"Total time: {total_time:.2f} seconds")
    
    return results

# For running in Jupyter notebook
def process_queries():
    return asyncio.run(run_processing())
